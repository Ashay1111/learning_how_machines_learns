# %% [markdown]
# # Polynomial Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('../Datasets/Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# ## Visualising the Simple Linear Regression results

# %%
plt.scatter(X,y, marker = 'o', label = 'original data', color = 'red')
plt.plot(X,lin_reg.predict(X), marker = 'x', label = 'predicted data')
plt.legend()
plt.title("Linear Regression")
plt.xlabel('Experience (years)')
plt.ylabel('salary ($)')
plt.show()

# %% [markdown]
# ## Training and Visualising the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures

#get the regressor
pr = PolynomialFeatures(degree = 2)
polyX = pr.fit_transform(X)

#Train the regressor
poly_reg = LinearRegression()
poly_reg.fit(polyX, y)

#visualize
plt.scatter(X,y, marker = 'o', label = 'original data', color = 'red')
plt.plot(X,poly_reg.predict(polyX), marker = 'x', label = 'predicted data')
plt.legend()
plt.title("Polynomial Regression (Degree : 2)")
plt.xlabel('Experience (years)')
plt.ylabel('salary ($)')
plt.show()

# %%
#get the regressor
pr = PolynomialFeatures(degree = 4)
polyX = pr.fit_transform(X)

#Train the regressor
poly_reg = LinearRegression()
poly_reg.fit(polyX, y)

#visualize
plt.scatter(X,y, marker = 'o', label = 'original data', color = 'red')
plt.plot(X,poly_reg.predict(polyX), marker = 'x', label = 'predicted data')
plt.legend()
plt.title("Polynomial Regression (Degree : 4)")
plt.xlabel('Experience (years)')
plt.ylabel('salary ($)')
plt.show()

# %% [markdown]
# ## Predicting a new result with Linear Regression

# %%
lin_reg.predict([[6.5]]) #should be $160,000
# Out:
# array([330378.78787879])

# %% [markdown]
# ## Predicting a new result with Polynomial Regression

# %%
poly_reg.predict(pr.fit_transform([[6.51]])) #should be $160,000
# Out:
# array([159252.43156778])

# %% [markdown]
# Here, Polynomial Regression gives more accurate results.

# %% [markdown]
# # Visualising the Polynomial Regression results (for higher resolution and smoother curve)

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))

plt.scatter(X, y, color = 'red')
plt.plot(X_grid, poly_reg.predict(pr.fit_transform(X_grid)), color = 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()
# Out:
# /var/folders/vp/4637syr17gq79cb8mjcw_gb40000gn/T/ipykernel_49762/2867862783.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X), max(X), 0.1)
